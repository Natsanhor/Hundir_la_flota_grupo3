# %%
pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl (12.8 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.3.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

class Tablero :
    def __init__(self , id_jugador, filas=10, columnas=10 , agua="~"):
        self.filas = filas
        self.columnas = columnas
        self.id_jugador= id_jugador
        self.agua = agua

    def crear_tablero (self):
        self.tablero=np.full((self.filas, self.columnas), self.agua)
        self.tablero_mascara = self.tablero.copy()
        return self.tablero
    

    def coloca_barco(self, barco):
    # Nos devuelve el tablero si puede colocar el barco, si no devuelve False, y avise por pantalla
        tablero_temp = self.tablero.copy()  #hago una copia del tablero y trabajo con ella 
        num_max_filas = self.tablero.shape[0]
        num_max_columnas = self.tablero.shape[1]
        for pieza in barco:
            fila = pieza[0]
            columna = pieza[1]
            if fila < 0  or fila >= num_max_filas:
                print(f"No puedo poner la pieza {pieza} porque se sale del tablero")
                return False
            if columna < 0 or columna >= num_max_columnas:
                print(f"No puedo poner la pieza {pieza} porque se sale del tablero")
                return False
            if self.tablero[pieza] == "O" or self.tablero[pieza] == "X":
                print(f"No puedo poner la pieza {pieza} porque hay otro barco")
                return False
        
            tablero_temp[pieza] = "O"
        return tablero_temp



tablero_jugador = Tablero("jugador") 
tablero_jugador.crear_tablero()

tablero_maquina = Tablero("maquina")
tablero_maquina.crear_tablero()
# Out:
# array([['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')

# %%
tablero_jugador.coloca_barco([(0,1),(1,1)])
# Out:
# array([['~', 'O', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', 'O', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')

# %%
tablero_jugador.tablero
# Out:
# array([['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')

# %%
class barco :
    def __init__ (self, eslora , nombre):
        self.eslora = eslora
        self.nombre= nombre


    def coloca_barco(self, tablero, barco):
    # Nos devuelve el tablero si puede colocar el barco, si no devuelve False, y avise por pantalla
        tablero_temp = tablero.copy()  #hago una copia del tablero y trabajo con ella 
        num_max_filas = tablero.shape[0]
        num_max_columnas = tablero.shape[1]
        for pieza in barco:
            fila = pieza[0]
            columna = pieza[1]
            if fila < 0  or fila >= num_max_filas:
                print(f"No puedo poner la pieza {pieza} porque se sale del tablero")
                return False
            if columna < 0 or columna >= num_max_columnas:
                print(f"No puedo poner la pieza {pieza} porque se sale del tablero")
                return False
            if tablero[pieza] == "O" or tablero[pieza] == "X":
                print(f"No puedo poner la pieza {pieza} porque hay otro barco")
                return False
        
            tablero_temp[pieza] = "O"
        return tablero_temp

# %%
barco_jugador= barco(2,"barco1")
barco_jugador.coloca_barco(tablero_jugador, [(1,1),(1,2)])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 2
#       1 barco_jugador= barco(2,"barco1")
# ----> 2 barco_jugador.coloca_barco(tablero_jugador, [(1,1),(1,2)])
#
# Cell In[59], line 10, in barco.coloca_barco(self, tablero, barco)
#       7 def coloca_barco(self, tablero, barco):
#       8 # Nos devuelve el tablero si puede colocar el barco, si no devuelve False, y avise por pantalla
#       9     tablero_temp = tablero  #hago una copia del tablero y trabajo con ella
# ---> 10     num_max_filas = tablero.shape[0]
#      11     num_max_columnas = tablero.shape[1]
#      12     for pieza in barco:
#
# AttributeError: 'tablero' object has no attribute 'shape'
